# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment; for example, when you flip a coin, it can be either head or tails.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result


# n_experiments = 100
# probability = 0.5

# data = range(n_experiments)
# pmf = binom.pmf(data, n_experiments, probability)

# plt.figure(figsize = (10, 5))
# plt.stem(data, pmf)
# plt.show()

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution, where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %%
# TODO
# import numpy as np
from scipy.stats import norm




def dnorm(x, mean = 0, sigma=1):
  
    # Calculates the normal distribution
   
    result = norm.pdf(x, scale=sigma, loc = mean)

    return result

def pnorm(x, mean = 0, sigma=1):

    # Calculates the cumulative of the normal distribution

    result = norm.cdf(x = x, scale=sigma, loc = mean)

    return result

def qnorm(p, mean = 0, sigma=1):

    # Calculates the quantile function from the normal distribution
    
    result = norm.ppf(q = p, scale=sigma, loc = mean)

    return result

def rnorm(n, mean = 0, sigma=1):
   
    # Generates random variables from the normal distribution
   
    result = norm.rvs(size= n, scale=sigma, loc = mean)

    return result

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)

mean = 0
std = 1
data = np.linspace(-5, 5, 1000)


pdf = dnorm(data, mean = mean, sigma = std)
cdf = pnorm(data, mean = mean, sigma = std)
ppf = qnorm(data, mean = mean, sigma = std)


fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pdf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")


# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
from scipy.stats import uniform




def dunifor(x, l = -2, s = 1):
  
    # Calculates the uniform distribution
   
    result = uniform.pdf(x, loc = l, scale=s )

    return result

def puniform(x, l = -2, s = 1):

    # Calculates the cumulative of the uniform distribution

    result = uniform.cdf(x = x, scale=s, loc = l)

    return result

def quniform(p, l = -2, s = 1):

    # Calculates the quantile function from the normal distribution
    
    result = uniform.ppf(q = p, scale=s, loc = l)

    return result

def rnorm(n, l = -2, s = 1):
   
    # Generates random variables from the normal distribution
   
    result = norm.rvs(size= n, scale=s, loc = l)

    return result

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)

l = -2
s = 1
data = np.linspace(-5, 5, 1000)


pdf = dunifor(data, l = l, s = s)
cdf = puniform(data, l = l, s = s)
ppf = quniform(data, l = l, s = s)


fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pdf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")


# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()
